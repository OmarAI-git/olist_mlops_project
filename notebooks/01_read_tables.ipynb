# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import pyodbc

print(pd.__version__)
# Out:
# 3.0.5

# %% [markdown]
# ### Loading the database

# %%
connect = pyodbc.connect(
    "Driver={ODBC Driver 17 for SQL Server};"
    r"Server=.\SQLEXPRESS;"
    "Database=MLOps_qafza;"
    "Trusted_Connection=yes;"
)

# %% [markdown]
# ### Making some query

# %%
query = '''
    SELECT TOP 10 
	od.order_id,
	od.order_status,
	od.order_delivered_customer_date,
	od.order_estimated_delivery_date,
	oid.price,
	oid.shipping_limit_date,
	opd.payment_type,
	opd.payment_value
FROM dbo.olist_orders_dataset AS od
JOIN dbo.olist_order_items_dataset AS oid
ON od.order_id = oid.order_id
JOIN dbo.olist_order_payments_dataset AS opd
ON od.order_id = opd.order_id
'''


mask = pd.read_sql(query, connect)

mask
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11704\915346644.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   mask = pd.read_sql(query, connect)
#                            order_id order_status  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered
# 1  e481f51cbdc54678b7cc49136f2d6af7    delivered
# 2  e481f51cbdc54678b7cc49136f2d6af7    delivered
# 3  53cdb2fc8bc7dce0b6741e2150273451    delivered
# 4  47770eb9100c2d0c44946d9cf07ec65d    delivered
# 5  949d5b44dbf5de918fe9c16f97b45f8a    delivered
# 6  ad21c59c0840e6cb83a9ceb5573f8159    delivered
# 7  a4591c265e18cb1dcee52889e2d8acc3    delivered
# 8  136cce7faa42fdb2cefd53fdc79a6098     invoiced
# 9  6514b8ad8028c9f2cc2374ded245783f    delivered
#
#   order_delivered_customer_date order_estimated_delivery_date       price  \
# ...

# %% [markdown]
# ### Work with tables

# %%
customers = pd.read_sql('SELECT * FROM dbo.olist_customers_dataset', connect)

sellers = pd.read_sql('SELECT * FROM dbo.olist_sellers_dataset', connect)

products = pd.read_sql('SELECT * FROM dbo.olist_products_dataset', connect)

product_category_name_translation = pd.read_sql('SELECT * FROM dbo.product_category_name_translation', connect)

geolocation = pd.read_sql('SELECT * FROM dbo.olist_geolocation_dataset', connect)

orders = pd.read_sql('SELECT * FROM dbo.olist_orders_dataset', connect)

order_items = pd.read_sql('SELECT * FROM dbo.olist_order_items_dataset', connect)

order_payments = pd.read_sql('SELECT * FROM dbo.olist_order_payments_dataset', connect)

order_reviews = pd.read_sql('SELECT * FROM dbo.olist_order_reviews_dataset', connect)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11704\2317773807.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customers = pd.read_sql('SELECT * FROM dbo.olist_customers_dataset', connect)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11704\2317773807.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sellers = pd.read_sql('SELECT * FROM dbo.olist_sellers_dataset', connect)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11704\2317773807.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %% [markdown]
# #### Shape of the tables

# %%
tables = {
    'Orders': orders,
    'Order Items': order_items,
    'Order Payments': order_payments,
    'Order Reviews': order_reviews,
    'Customers': customers,
    'Sellers': sellers,
    'Products': products,
    'Geolocation': geolocation,
    'Product Category Name Translation': product_category_name_translation
}

for name, df in tables.items():
    print(f'{name} shape -> {df.shape}')
# Out:
# Orders shape -> (99441, 8)
# Order Items shape -> (112650, 7)
# Order Payments shape -> (103886, 5)
# Order Reviews shape -> (99224, 7)
# Customers shape -> (99441, 5)
# Sellers shape -> (3095, 4)
# Products shape -> (32951, 9)
# Geolocation shape -> (1000163, 5)
# Product Category Name Translation shape -> (72, 2)

# %% [markdown]
# #### First two rows from tables

# %%
customers.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP

# %%
sellers.head(2)
# Out:
#                           seller_id  seller_zip_code_prefix seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
#
#   seller_state
# 0           SP
# 1           SP

# %%
products.head(2)
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0

# %%
product_category_name_translation.head(2)
# Out:
#                  column1                        column2
# 0  product_category_name  product_category_name_english
# 1           beleza_saude                  health_beauty

# %%
geolocation.head(2)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545622       -46.639294
# 1                         1046       -23.546082       -46.644821
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP

# %%
orders.head(2)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13

# %%
order_items.head(2)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
#
#   shipping_limit_date       price  freight_value
# 0 2017-09-19 09:45:35   58.900002          13.29
# 1 2017-05-03 11:05:13  239.899994          19.93

# %%
order_payments.head(2)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8      99.330002
# 1                     1      24.389999

# %%
order_reviews.head(2)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0           2018-01-18     2018-01-18 21:46:59
# 1           2018-03-10     2018-03-11 03:05:13

# %% [markdown]
# #### Check duplicates

# %%
for name, df in tables.items():
    if True in df.duplicated():
        print(f'Number of duplicates in {name} table is: {df.duplicated().sum()}')

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Check uniqueness

# %%
print(f'customer id is unique in customers table? {customers['customer_id'].is_unique}')
print(f'seller id is unique in sellers table? {sellers['seller_id'].is_unique}')
print(f'product id is unique in products table? {products['product_id'].is_unique}')
print(f'order id is unique in orders table? {orders['order_id'].is_unique}')
print(f'order id is unique in order items table? {order_items['order_id'].is_unique}')
print(f'order id is unique in order payments table? {order_payments['order_id'].is_unique}')
print(f'order id is unique in order reviews table? {order_reviews['order_id'].is_unique}')
# Out:
# customer id is unique in customers table? True
# seller id is unique in sellers table? True
# product id is unique in products table? True
# order id is unique in orders table? True
# order id is unique in order items table? False
# order id is unique in order payments table? False
# order id is unique in order reviews table? False

# %%
order_items[['order_id', 'order_item_id']].duplicated().sum()
# Out:
# np.int64(0)

# %%
order_reviews[['order_id', 'review_id']].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Aggregation

# %%
order_items_agg = pd.read_sql('''SELECT 
	order_id,
	COUNT(order_item_id) AS item_count,
	SUM(price) AS total_price,
	SUM(freight_value) AS total_freight_value
FROM dbo.olist_order_items_dataset
GROUP BY order_id
''', connect)

order_items_agg
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11704\1644565933.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_items_agg = pd.read_sql('''SELECT
#                                order_id  item_count  total_price  \
# 0      8e8f8ef29c78c7b9c98cac70dd331ce2           6  1020.000000
# 1      061f31c732cb84a989d5b62660212ecc           1    69.989998
# 2      fb5114c39f632a52598cf770c6076620           1    35.000000
# 3      23fb5e6768dd0cf8df7aaa74d80f8ec6           1    55.000000
# 4      7581c7decedb7d7f4310ef8313f935a7           1    34.900002
# ...                                 ...         ...          ...
# 98661  50cb3b5a9be182d708715a0ea7d488b0           1    24.900000
# 98662  73627dfa9a67ee111fb528be6f9d4b02           1    34.990002
# 98663  07220c39eb26068368e675009154d635           1   136.000000
# ...

# %%
order_payments_agg = pd.read_sql('''SELECT
    order_id,
    COUNT(*) AS payment_count,
	SUM(payment_value) AS total_payment
FROM dbo.olist_order_payments_dataset
GROUP BY order_id;
''', connect)

order_payments_agg
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11704\816732954.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_payments_agg = pd.read_sql('''SELECT
#                                order_id  payment_count  total_payment
# 0      d5a777d0e1c561e945c9eedce2cad80f              1      58.740002
# 1      ceaa40707ccad8de8d4dab476a970483              1      85.239998
# 2      aeef04fa986be504dfc33b096ac921df              1      94.309998
# 3      b12dbb55013ad2916d26c65c8abbcd17              1     226.580002
# 4      6cff0bbcafb7486dd85cda3c8171cf9a              1     253.899994
# ...                                 ...            ...            ...
# 99435  cab86f1b8802835f13e9fee67ae7ee13              1     206.139999
# 99436  78ef246c8a753452a6464f1f66603fac              1      88.559998
# ...

# %% [markdown]
# ### Build ML table

# %%
ml_table = pd.read_sql('''SELECT 
	o.order_id,
	o.customer_id,
	o.order_status,
	o.order_purchase_timestamp,
	o.order_approved_at,
	o.order_delivered_carrier_date,
	o.order_delivered_customer_date,
	o.order_estimated_delivery_date,

	c.customer_unique_id,
	c.customer_city,
	c.customer_state,
	c.customer_zip_code_prefix,

	i.item_count,
	i.total_price,
	i.total_freight_value,

	pay.payment_count,
	pay.total_payment,

	pro.avg_product_name_length,
	pro.avg_product_description_length,
	pro.avg_product_height_cm,
	pro.avg_product_length_cm,
	pro.avg_product_photos_qty,
	pro.avg_product_width_cm,
	pro.avg_product_weight_g,
	pro.product_count,

	sel.seller_count
FROM dbo.olist_orders_dataset AS o
LEFT JOIN dbo.olist_customers_dataset AS c
ON o.customer_id = c.customer_id
LEFT JOIN (
SELECT 
	order_id,
	COUNT(order_item_id) AS item_count,
	SUM(price) AS total_price,
	SUM(freight_value) AS total_freight_value
FROM dbo.olist_order_items_dataset
GROUP BY order_id) AS i
ON o.order_id = i.order_id
LEFT JOIN (
SELECT
	order_id,
	COUNT(*) AS payment_count,
	SUM(payment_value) AS total_payment
FROM dbo.olist_order_payments_dataset
GROUP BY order_id) AS pay
ON o.order_id = pay.order_id
LEFT JOIN (
SELECT 
	oi.order_id,
	COUNT(DISTINCT oi.product_id) AS product_count,
	AVG(pro.product_height_cm) AS avg_product_height_cm,
	AVG(pro.product_description_lenght) AS avg_product_description_length,
	AVG(pro.product_length_cm) AS avg_product_length_cm,
	AVG(pro.product_name_lenght) AS avg_product_name_length,
	AVG(pro.product_photos_qty) AS avg_product_photos_qty,
	AVG(pro.product_weight_g) AS avg_product_weight_g,
	AVG(pro.product_width_cm) AS avg_product_width_cm
FROM dbo.olist_order_items_dataset AS oi
LEFT JOIN dbo.olist_products_dataset AS pro
ON oi.product_id = pro.product_id
GROUP BY oi.order_id
) AS pro
ON o.order_id = pro.order_id
LEFT JOIN (
SELECT
	oi.order_id,
	COUNT(DISTINCT oi.seller_id) AS seller_count
FROM dbo.olist_order_items_dataset AS oi
GROUP BY oi.order_id) AS sel
ON o.order_id = sel.order_id''', connect)

ml_table
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4148\4227996093.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ml_table = pd.read_sql('''SELECT
#                                order_id                       customer_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1      00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2      000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3      00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4      00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
# ...                                 ...                               ...
# 99436  fffc94f6ce00a00581880bf54a75a037  b51593916b4b8e0d6f66f2ae24f2673d
# 99437  fffcd46ef2263f404302a634eb57f7eb  84c5d4fbaf120aae381fad077416eaa0
# ...

# %%
ml_table.to_parquet('../data/artifacts/01_ml_table.parquet')

# %%
pd.read_parquet('../data/artifacts/01_ml_table.parquet')
# Out:
#                                order_id                       customer_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1      00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2      000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3      00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4      00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
# ...                                 ...                               ...
# 99436  fffc94f6ce00a00581880bf54a75a037  b51593916b4b8e0d6f66f2ae24f2673d
# 99437  fffcd46ef2263f404302a634eb57f7eb  84c5d4fbaf120aae381fad077416eaa0
# 99438  fffce4705a9662cd70adb13d4a31832d  29309aa813182aaddc9b259e31b870e6
# 99439  fffe18544ffabc95dfada21779c9644f  b5e6afd5a41800fdf401e0272ca74655
# 99440  fffe41c64501cc87c801fd61db3f6244  96d649da0cc4ff33bb408b199d4c7dcf
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...
